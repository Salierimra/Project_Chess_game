# %%
pip install chess.com
# Out:
# Requirement already satisfied: chess.com in c:\users\rasse\appdata\local\programs\python\python311\lib\site-packages (3.13.0)
# Requirement already satisfied: aiohttp>=3 in c:\users\rasse\appdata\local\programs\python\python311\lib\site-packages (from chess.com) (3.13.2)
# Requirement already satisfied: requests>=2 in c:\users\rasse\appdata\local\programs\python\python311\lib\site-packages (from chess.com) (2.32.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\rasse\appdata\local\programs\python\python311\lib\site-packages (from aiohttp>=3->chess.com) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\rasse\appdata\local\programs\python\python311\lib\site-packages (from aiohttp>=3->chess.com) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\rasse\appdata\local\programs\python\python311\lib\site-packages (from aiohttp>=3->chess.com) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\rasse\appdata\local\programs\python\python311\lib\site-packages (from aiohttp>=3->chess.com) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\rasse\appdata\local\programs\python\python311\lib\site-packages (from aiohttp>=3->chess.com) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\rasse\appdata\local\programs\python\python311\lib\site-packages (from aiohttp>=3->chess.com) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\rasse\appdata\local\programs\python\python311\lib\site-packages (from aiohttp>=3->chess.com) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\rasse\appdata\local\programs\python\python311\lib\site-packages (from requests>=2->chess.com) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rasse\appdata\local\programs\python\python311\lib\site-packages (from requests>=2->chess.com) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rasse\appdata\local\programs\python\python311\lib\site-packages (from requests>=2->chess.com) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rasse\appdata\local\programs\python\python311\lib\site-packages (from requests>=2->chess.com) (2025.11.12)
# Requirement already satisfied: typing-extensions>=4.2 in c:\users\rasse\appdata\roaming\python\python311\site-packages (from aiosignal>=1.4.0->aiohttp>=3->chess.com) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import time
import pandas as pd
import requests
from chessdotcom import ChessDotComClient
import numpy as np

# %%
def parcourir_avec_delai(liste_liens):
    '''
    Cette fonction recupere une liste de lien json [08/2013,09/2013,...] 
    represantant les parties jouées a un mois donné
    '''
    tous_les_jeux = []
    
    # IMPORTANT : Ajouter un User-Agent
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
    }
    for i, url in enumerate(liste_liens):
        try:
            print(f"Récupération {i+1}/{len(liste_liens)}: {url}")
            response = requests.get(url,headers=headers)
            response.raise_for_status()
            data = response.json() #{'games': [{'url': 'https://www.chess.com/game/daily/74856790', 'pgn': '[Event "Let\'s Play!"]\n[Site "Chess.com"]\n[Da
            
            tous_les_jeux.extend(data['games'])#extrait la liste'games
            
            # Pause pour ne pas surcharger l'API
            time.sleep(0.5)
            
        except requests.exceptions.RequestException as e:
            print(f"Erreur pour {url}: {e}")
    
    return tous_les_jeux #retourne toutes les parties

# %%
import re

def extraire_opening_robuste(pgn):
    """
    Extrait le nom de l'ouverture de manière robuste
    Args :
        - rubrique pgn du fichier json

    output : extract l'opening ou N/A
    """
    # Chercher l'ECOUrl avec regex
    match = re.search(r'\[ECOUrl "https://www\.chess\.com/openings/([^"]+)"\]', pgn)
    if match:
        return match.group(1)
    
    # Fallback si regex échoue
    idx = pgn.find("https://www.chess.com/openings/")
    if idx != -1:
        start = idx + 33
        end = pgn.find('"', start) #-1 si n'existe pas
        if end != -1:
            return pgn[start:end]
    
    return 'N/A'

# %%
dictionnaire_partie = {'Player white' : [],'Player Black' : [],'Result white':[],'Result black':[],'Date Partie':[],'Heure partie':[],'ELO white': [], 'ELO black':[],'Openning':[],'Time control':[],'Liste des coups':[]}
df = pd.DataFrame(dictionnaire_partie)
df
# Out:
# Empty DataFrame
# Columns: [Player white, Player Black, Result white, Result black, Date Partie, Heure partie, ELO white, ELO black, Openning, Time control, Liste des coups]
# Index: []

# %%
   
client = ChessDotComClient(user_agent = "My Python Application...")

response = client.get_player_profile("Tuco007")#recuperation des données du profil "Tuco007"

print("*"*50)
print(f"je suis : {response.player.name}") # Affichage du nom 
Tuco_stats = client.get_player_stats(username="Tuco007") #recuperation des stats de Tuco007
print(f"Blitz elo : {Tuco_stats.stats.chess_blitz.last.rating} pic elo : {Tuco_stats.stats.chess_blitz.best.rating} ")
print(f"Rapid elo : {Tuco_stats.stats.chess_rapid.last.rating}  pic elo : {Tuco_stats.stats.chess_rapid.best.rating}")
print(f"Classique elo : {Tuco_stats.stats.chess_daily.last.rating}  pic elo : {Tuco_stats.stats.chess_daily.best.rating}")
response.player

archive = client.get_player_game_archives(username="Tuco007")#recupere toutes les parties du joueur depuis qu'il a join le site
archive_json = archive.json #recupere en json

dictionnaire_partie = {'Player white' : [],'Player black' : [],'Result white':[],'Result black':[],'Date partie':[],'Heure partie':[],'ELO white': [], 'ELO black':[],'Openning':[],'Time control':[],'Liste des coups':[]}

#archive_json : {archives : [games08/2013,08/2013,....]}
#archive_json[archives] : recupere la liste [games08/2013,08/2013,....]}}

all_games = parcourir_avec_delai(archive_json["archives"])

#creation d'un dictionnaire ou les clefs sont les paramètres à recuperer et les valeurs sont les valeurs a recuperer
for j in range(len(all_games)):
    dictionnaire_partie['Player white'].append(all_games[j]['white']['username'])
    dictionnaire_partie['Player black'].append(all_games[j]['black']['username'])
    
    dictionnaire_partie['Result white'].append(all_games[j]['white']['result'])
    dictionnaire_partie['Result black'].append(all_games[j]['black']['result'])

    indice_date = all_games[j]['pgn'].find("Date") #trouver l'indice de la position DATE dans la rubrique pdn du json
    dictionnaire_partie['Date partie'].append(all_games[j]['pgn'][indice_date+6:indice_date+6+10])

    indice_heure = all_games[j]['pgn'].find("UTCTime") #trouver l'indice de la position UTCDate dans la rubrique pdn du json (pour trouver l'heure)
    dictionnaire_partie['Heure partie'].append(all_games[j]['pgn'][indice_heure+9:indice_heure+9+8])

    dictionnaire_partie['ELO white'].append(all_games[j]['white']['rating'])
    dictionnaire_partie['ELO black'].append(all_games[j]['black']['rating'])

    opening = extraire_opening_robuste(all_games[j]['pgn'])
   
    dictionnaire_partie['Openning'].append(opening)

    dictionnaire_partie['Time control'].append(all_games[j]['time_control'])

    startlistecoups = all_games[j]['pgn'].find("]\n\n1.")#trouver l'endroit ou commence la liste des coups dans pgn
    dictionnaire_partie['Liste des coups'].append(all_games[j]['pgn'][startlistecoups+2:])
    

df = pd.DataFrame(dictionnaire_partie)
# Out:
# **************************************************
# je suis : Max Rasseneur
# Blitz elo : 1297 pic elo : 1497
# Rapid elo : 1652  pic elo : 1870
# Classique elo : 1455  pic elo : 1543
# Récupération 1/130: https://api.chess.com/pub/player/tuco007/games/2013/08
# Récupération 2/130: https://api.chess.com/pub/player/tuco007/games/2013/09
# Récupération 3/130: https://api.chess.com/pub/player/tuco007/games/2013/10
# Récupération 4/130: https://api.chess.com/pub/player/tuco007/games/2013/11
# Récupération 5/130: https://api.chess.com/pub/player/tuco007/games/2013/12
# Récupération 6/130: https://api.chess.com/pub/player/tuco007/games/2014/01
# Récupération 7/130: https://api.chess.com/pub/player/tuco007/games/2014/02
# Récupération 8/130: https://api.chess.com/pub/player/tuco007/games/2014/03
# Récupération 9/130: https://api.chess.com/pub/player/tuco007/games/2014/04
# Récupération 10/130: https://api.chess.com/pub/player/tuco007/games/2014/05
# Récupération 11/130: https://api.chess.com/pub/player/tuco007/games/2014/06
# Récupération 12/130: https://api.chess.com/pub/player/tuco007/games/2014/07
# Récupération 13/130: https://api.chess.com/pub/player/tuco007/games/2014/08
# Récupération 14/130: https://api.chess.com/pub/player/tuco007/games/2014/09
# Récupération 15/130: https://api.chess.com/pub/player/tuco007/games/2014/10
# Récupération 16/130: https://api.chess.com/pub/player/tuco007/games/2014/11
# Récupération 17/130: https://api.chess.com/pub/player/tuco007/games/2014/12
# Récupération 18/130: https://api.chess.com/pub/player/tuco007/games/2015/01
# Récupération 19/130: https://api.chess.com/pub/player/tuco007/games/2015/02
# Récupération 20/130: https://api.chess.com/pub/player/tuco007/games/2015/03
# Récupération 21/130: https://api.chess.com/pub/player/tuco007/games/2015/04
# Récupération 22/130: https://api.chess.com/pub/player/tuco007/games/2015/05
# Récupération 23/130: https://api.chess.com/pub/player/tuco007/games/2015/06
# Récupération 24/130: https://api.chess.com/pub/player/tuco007/games/2015/07
# Récupération 25/130: https://api.chess.com/pub/player/tuco007/games/2015/08
# Récupération 26/130: https://api.chess.com/pub/player/tuco007/games/2015/09
# Récupération 27/130: https://api.chess.com/pub/player/tuco007/games/2015/10
# Récupération 28/130: https://api.chess.com/pub/player/tuco007/games/2015/11
# Récupération 29/130: https://api.chess.com/pub/player/tuco007/games/2015/12
# Récupération 30/130: https://api.chess.com/pub/player/tuco007/games/2016/01
# Récupération 31/130: https://api.chess.com/pub/player/tuco007/games/2016/02
# Récupération 32/130: https://api.chess.com/pub/player/tuco007/games/2016/03
# Récupération 33/130: https://api.chess.com/pub/player/tuco007/games/2016/05
# Récupération 34/130: https://api.chess.com/pub/player/tuco007/games/2016/07
# Récupération 35/130: https://api.chess.com/pub/player/tuco007/games/2016/08
# Récupération 36/130: https://api.chess.com/pub/player/tuco007/games/2016/12
# Récupération 37/130: https://api.chess.com/pub/player/tuco007/games/2017/07
# Récupération 38/130: https://api.chess.com/pub/player/tuco007/games/2017/08
# Récupération 39/130: https://api.chess.com/pub/player/tuco007/games/2017/09
# Récupération 40/130: https://api.chess.com/pub/player/tuco007/games/2017/10
# Récupération 41/130: https://api.chess.com/pub/player/tuco007/games/2017/11
# Récupération 42/130: https://api.chess.com/pub/player/tuco007/games/2017/12
# Récupération 43/130: https://api.chess.com/pub/player/tuco007/games/2018/01
# Récupération 44/130: https://api.chess.com/pub/player/tuco007/games/2018/02
# Récupération 45/130: https://api.chess.com/pub/player/tuco007/games/2018/03
# Récupération 46/130: https://api.chess.com/pub/player/tuco007/games/2018/04
# Récupération 47/130: https://api.chess.com/pub/player/tuco007/games/2018/05
# Récupération 48/130: https://api.chess.com/pub/player/tuco007/games/2018/06
# Récupération 49/130: https://api.chess.com/pub/player/tuco007/games/2018/07
# Récupération 50/130: https://api.chess.com/pub/player/tuco007/games/2018/08
# Récupération 51/130: https://api.chess.com/pub/player/tuco007/games/2018/09
# Récupération 52/130: https://api.chess.com/pub/player/tuco007/games/2018/10
# Récupération 53/130: https://api.chess.com/pub/player/tuco007/games/2018/11
# Récupération 54/130: https://api.chess.com/pub/player/tuco007/games/2018/12
# Récupération 55/130: https://api.chess.com/pub/player/tuco007/games/2019/01
# Récupération 56/130: https://api.chess.com/pub/player/tuco007/games/2019/02
# Récupération 57/130: https://api.chess.com/pub/player/tuco007/games/2019/03
# Récupération 58/130: https://api.chess.com/pub/player/tuco007/games/2019/04
# Récupération 59/130: https://api.chess.com/pub/player/tuco007/games/2019/05
# Récupération 60/130: https://api.chess.com/pub/player/tuco007/games/2019/06
# Récupération 61/130: https://api.chess.com/pub/player/tuco007/games/2019/07
# Récupération 62/130: https://api.chess.com/pub/player/tuco007/games/2019/08
# Récupération 63/130: https://api.chess.com/pub/player/tuco007/games/2019/09
# Récupération 64/130: https://api.chess.com/pub/player/tuco007/games/2019/10
# Récupération 65/130: https://api.chess.com/pub/player/tuco007/games/2019/11
# Récupération 66/130: https://api.chess.com/pub/player/tuco007/games/2019/12
# Récupération 67/130: https://api.chess.com/pub/player/tuco007/games/2020/03
# Récupération 68/130: https://api.chess.com/pub/player/tuco007/games/2020/05
# Récupération 69/130: https://api.chess.com/pub/player/tuco007/games/2020/07
# Récupération 70/130: https://api.chess.com/pub/player/tuco007/games/2020/08
# Récupération 71/130: https://api.chess.com/pub/player/tuco007/games/2020/09
# Récupération 72/130: https://api.chess.com/pub/player/tuco007/games/2020/10
# Récupération 73/130: https://api.chess.com/pub/player/tuco007/games/2020/11
# Récupération 74/130: https://api.chess.com/pub/player/tuco007/games/2020/12
# Récupération 75/130: https://api.chess.com/pub/player/tuco007/games/2021/01
# Récupération 76/130: https://api.chess.com/pub/player/tuco007/games/2021/02
# Récupération 77/130: https://api.chess.com/pub/player/tuco007/games/2021/03
# Récupération 78/130: https://api.chess.com/pub/player/tuco007/games/2021/04
# Récupération 79/130: https://api.chess.com/pub/player/tuco007/games/2021/06
# Récupération 80/130: https://api.chess.com/pub/player/tuco007/games/2021/07
# Récupération 81/130: https://api.chess.com/pub/player/tuco007/games/2021/08
# Récupération 82/130: https://api.chess.com/pub/player/tuco007/games/2021/12
# Récupération 83/130: https://api.chess.com/pub/player/tuco007/games/2022/01
# Récupération 84/130: https://api.chess.com/pub/player/tuco007/games/2022/02
# Récupération 85/130: https://api.chess.com/pub/player/tuco007/games/2022/03
# Récupération 86/130: https://api.chess.com/pub/player/tuco007/games/2022/04
# Récupération 87/130: https://api.chess.com/pub/player/tuco007/games/2022/05
# Récupération 88/130: https://api.chess.com/pub/player/tuco007/games/2022/06
# Récupération 89/130: https://api.chess.com/pub/player/tuco007/games/2022/07
# Récupération 90/130: https://api.chess.com/pub/player/tuco007/games/2022/08
# Récupération 91/130: https://api.chess.com/pub/player/tuco007/games/2022/09
# Récupération 92/130: https://api.chess.com/pub/player/tuco007/games/2022/10
# Récupération 93/130: https://api.chess.com/pub/player/tuco007/games/2022/11
# Récupération 94/130: https://api.chess.com/pub/player/tuco007/games/2022/12
# Récupération 95/130: https://api.chess.com/pub/player/tuco007/games/2023/01
# Récupération 96/130: https://api.chess.com/pub/player/tuco007/games/2023/02
# Récupération 97/130: https://api.chess.com/pub/player/tuco007/games/2023/03
# Récupération 98/130: https://api.chess.com/pub/player/tuco007/games/2023/04
# Récupération 99/130: https://api.chess.com/pub/player/tuco007/games/2023/05
# Récupération 100/130: https://api.chess.com/pub/player/tuco007/games/2023/06
# Récupération 101/130: https://api.chess.com/pub/player/tuco007/games/2023/07
# Récupération 102/130: https://api.chess.com/pub/player/tuco007/games/2023/08
# Récupération 103/130: https://api.chess.com/pub/player/tuco007/games/2023/09
# Récupération 104/130: https://api.chess.com/pub/player/tuco007/games/2023/10
# Récupération 105/130: https://api.chess.com/pub/player/tuco007/games/2023/11
# Récupération 106/130: https://api.chess.com/pub/player/tuco007/games/2023/12
# Récupération 107/130: https://api.chess.com/pub/player/tuco007/games/2024/01
# Récupération 108/130: https://api.chess.com/pub/player/tuco007/games/2024/02
# Récupération 109/130: https://api.chess.com/pub/player/tuco007/games/2024/03
# Récupération 110/130: https://api.chess.com/pub/player/tuco007/games/2024/04
# Récupération 111/130: https://api.chess.com/pub/player/tuco007/games/2024/05
# Récupération 112/130: https://api.chess.com/pub/player/tuco007/games/2024/06
# Récupération 113/130: https://api.chess.com/pub/player/tuco007/games/2024/07
# Récupération 114/130: https://api.chess.com/pub/player/tuco007/games/2024/08
# Récupération 115/130: https://api.chess.com/pub/player/tuco007/games/2024/09
# Récupération 116/130: https://api.chess.com/pub/player/tuco007/games/2024/10
# Récupération 117/130: https://api.chess.com/pub/player/tuco007/games/2024/11
# Récupération 118/130: https://api.chess.com/pub/player/tuco007/games/2024/12
# Récupération 119/130: https://api.chess.com/pub/player/tuco007/games/2025/01
# Récupération 120/130: https://api.chess.com/pub/player/tuco007/games/2025/02
# Récupération 121/130: https://api.chess.com/pub/player/tuco007/games/2025/03
# Récupération 122/130: https://api.chess.com/pub/player/tuco007/games/2025/04
# Récupération 123/130: https://api.chess.com/pub/player/tuco007/games/2025/05
# Récupération 124/130: https://api.chess.com/pub/player/tuco007/games/2025/06
# Récupération 125/130: https://api.chess.com/pub/player/tuco007/games/2025/07
# Récupération 126/130: https://api.chess.com/pub/player/tuco007/games/2025/08
# Récupération 127/130: https://api.chess.com/pub/player/tuco007/games/2025/09
# Récupération 128/130: https://api.chess.com/pub/player/tuco007/games/2025/10
# Récupération 129/130: https://api.chess.com/pub/player/tuco007/games/2025/11
# Récupération 130/130: https://api.chess.com/pub/player/tuco007/games/2025/12

# %%
#check NULL values
df.isnull().sum()
# Out:
# Player white       0
# Player black       0
# Result white       0
# Result black       0
# Date partie        0
# Heure partie       0
# ELO white          0
# ELO black          0
# Openning           0
# Time control       0
# Liste des coups    0
# dtype: int64

# %%
#suprimons les lignes ou il n'y a pas d'openning
df_parties=df[df["Openning"]!="N/A"]

# %%
#valeurs uniques dans le DF
df_parties.nunique()
# Out:
# Player white        5344
# Player black        5323
# Result white          10
# Result black          10
# Date partie         1884
# Heure partie       11241
# ELO white           1210
# ELO black           1180
# Openning            2999
# Time control          19
# Liste des coups    12419
# dtype: int64

# %%
#Pre processing (a ne lancer qu'une fois)
df_parties["Date partie"]=df_parties["Date partie"].str.replace(".","/")
df_parties["Date partie"]=df_parties["Date partie"].str.strip()
# Out:
# C:\Users\rasse\AppData\Local\Temp\ipykernel_16844\3872083135.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_parties["Date partie"]=df_parties["Date partie"].str.replace(".","/")
# C:\Users\rasse\AppData\Local\Temp\ipykernel_16844\3872083135.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_parties["Date partie"]=df_parties["Date partie"].str.strip()

# %%
#Assurer le typage de heure et de date

df_parties["Date partie"]=pd.to_datetime(df_parties["Date partie"],format='%Y/%m/%d')
df_parties["Heure partie"]=pd.to_datetime(df_parties["Heure partie"],format='%H:%M:%S').dt.time
display(df_parties)
# Out:
# C:\Users\rasse\AppData\Local\Temp\ipykernel_16844\2152423122.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_parties["Date partie"]=pd.to_datetime(df_parties["Date partie"],format='%Y/%m/%d')
# C:\Users\rasse\AppData\Local\Temp\ipykernel_16844\2152423122.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_parties["Heure partie"]=pd.to_datetime(df_parties["Heure partie"],format='%H:%M:%S').dt.time
#       Player white        Player black Result white Result black Date partie  \
# 0        Rizzen_92             Tuco007   checkmated          win  2013-08-25
# 1          Tuco007           Rizzen_92          win   checkmated  2013-08-25
# 2        Rizzen_92             Tuco007   checkmated          win  2013-08-26
# 3          Tuco007           Rizzen_92          win   checkmated  2013-08-26
# 4        Rizzen_92             Tuco007   checkmated          win  2013-08-26
# ...            ...                 ...          ...          ...         ...
# 12417      Tuco007           Not_bad22          win      timeout  2025-12-20
# 12418      Tuco007           seif-hero          win     resigned  2025-12-20
# 12419      Tuco007  Dark_Demon_lord_OP      timeout          win  2025-12-20
# 12420      reevioo             Tuco007          win   checkmated  2025-12-20
# 12421      JLuce78             Tuco007      timeout          win  2025-12-21
#
#       Heure partie  ELO white  ELO black  \
# 0         09:21:42       1054       1346
# 1         09:23:02       1346       1054
# 2         09:44:23        997       1403
# 3         11:54:31       1435        965
# 4         13:40:14        943       1457
# ...            ...        ...        ...
# 12417     17:56:17       1297       1301
# 12418     18:01:54       1297        401
# 12419     18:07:12       1297       1619
# 12420     18:58:45       1220       1297
# 12421     07:24:54        915       1297
#
#                                                 Openning Time control  \
# 0                   Indian-Game-Fantasy-Variation-2...d5     1/259200
# 1              Kings-Pawn-Opening-Kings-Knight-Variation      1/86400
# 2              Kings-Pawn-Opening-Kings-Knight-Variation     1/259200
# 3                            Pirc-Defense-2.d4-Nf6-3.Nc3      1/86400
# 4                                           Pirc-Defense      1/86400
# ...                                                  ...          ...
# 12417  Giuoco-Piano-Game-Giuoco-Pianissimo-Variation-...          180
# 12418  Ruy-Lopez-Opening-Morphy-Defense-Caro-Variatio...          180
# 12419                 Owens-Defense...3.Nc3-e6-4.Bd3-Nf6          180
# 12420     Sicilian-Defense-Open-3...cxd4-4.Nxd4-d6-5.Nc3          180
# 12421  Slav-Defense-Modern-Exchange-Variation-4...cxd...          180
#
#                                          Liste des coups
# 0      \n1. d4 Nf6 2. f3 d5 3. Nc3 e6 4. a3 Nbd7 5. N...
# 1      \n1. e4 e5 2. Nf3 f6 3. d3 d6 4. d4 Nc6 5. dxe...
# 2      \n1. e4 e5 2. Nf3 f6 3. d4 Bb4+ 4. Ke2 d6 5. a...
# 3      \n1. e4 Nf6 2. Nc3 d6 3. d4 Bg4 4. Bb5+ c6 5. ...
# 4      \n1. e4 d6 2. Bb5+ Nc6 3. Nc3 Bd7 4. Nf3 e5 5....
# ...                                                  ...
# 12417  \n1. e4 {[%clk 0:02:57.7]} 1... e5 {[%clk 0:02...
# 12418  \n1. e4 {[%clk 0:02:56.9]} 1... e5 {[%clk 0:02...
# 12419  \n1. e4 {[%clk 0:02:57.9]} 1... b6 {[%clk 0:02...
# 12420  \n1. e4 {[%clk 0:02:59.9]} 1... c5 {[%clk 0:02...
# 12421  \n1. d4 {[%clk 0:02:58.7]} 1... d5 {[%clk 0:02...
#
# [12421 rows x 11 columns]

# %%
# Création Résultat myself
df_parties["Result maximilien"] = np.where(
    df_parties["Player white"] == "Tuco007",
    df_parties["Result white"],
    df_parties["Result black"]
)

# Création Résultat advsersaire
df_parties["Result adv"] = np.where(
    df_parties["Player white"] != "Tuco007",
    df_parties["Result white"],
    df_parties["Result black"]
)

df_parties
# Out:
# C:\Users\rasse\AppData\Local\Temp\ipykernel_16844\3617006998.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_parties["Result maximilien"] = np.where(
# C:\Users\rasse\AppData\Local\Temp\ipykernel_16844\3617006998.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_parties["Result adv"] = np.where(
#       Player white        Player black Result white Result black Date partie  \
# 0        Rizzen_92             Tuco007   checkmated          win  2013-08-25
# 1          Tuco007           Rizzen_92          win   checkmated  2013-08-25
# 2        Rizzen_92             Tuco007   checkmated          win  2013-08-26
# 3          Tuco007           Rizzen_92          win   checkmated  2013-08-26
# 4        Rizzen_92             Tuco007   checkmated          win  2013-08-26
# ...            ...                 ...          ...          ...         ...
# 12417      Tuco007           Not_bad22          win      timeout  2025-12-20
# 12418      Tuco007           seif-hero          win     resigned  2025-12-20
# 12419      Tuco007  Dark_Demon_lord_OP      timeout          win  2025-12-20
# 12420      reevioo             Tuco007          win   checkmated  2025-12-20
# 12421      JLuce78             Tuco007      timeout          win  2025-12-21
#
#       Heure partie  ELO white  ELO black  \
# 0         09:21:42       1054       1346
# 1         09:23:02       1346       1054
# 2         09:44:23        997       1403
# 3         11:54:31       1435        965
# 4         13:40:14        943       1457
# ...            ...        ...        ...
# 12417     17:56:17       1297       1301
# 12418     18:01:54       1297        401
# 12419     18:07:12       1297       1619
# 12420     18:58:45       1220       1297
# 12421     07:24:54        915       1297
#
#                                                 Openning Time control  \
# 0                   Indian-Game-Fantasy-Variation-2...d5     1/259200
# 1              Kings-Pawn-Opening-Kings-Knight-Variation      1/86400
# 2              Kings-Pawn-Opening-Kings-Knight-Variation     1/259200
# 3                            Pirc-Defense-2.d4-Nf6-3.Nc3      1/86400
# 4                                           Pirc-Defense      1/86400
# ...                                                  ...          ...
# 12417  Giuoco-Piano-Game-Giuoco-Pianissimo-Variation-...          180
# 12418  Ruy-Lopez-Opening-Morphy-Defense-Caro-Variatio...          180
# 12419                 Owens-Defense...3.Nc3-e6-4.Bd3-Nf6          180
# 12420     Sicilian-Defense-Open-3...cxd4-4.Nxd4-d6-5.Nc3          180
# 12421  Slav-Defense-Modern-Exchange-Variation-4...cxd...          180
#
#                                          Liste des coups Result maximilien  \
# 0      \n1. d4 Nf6 2. f3 d5 3. Nc3 e6 4. a3 Nbd7 5. N...               win
# 1      \n1. e4 e5 2. Nf3 f6 3. d3 d6 4. d4 Nc6 5. dxe...               win
# 2      \n1. e4 e5 2. Nf3 f6 3. d4 Bb4+ 4. Ke2 d6 5. a...               win
# 3      \n1. e4 Nf6 2. Nc3 d6 3. d4 Bg4 4. Bb5+ c6 5. ...               win
# 4      \n1. e4 d6 2. Bb5+ Nc6 3. Nc3 Bd7 4. Nf3 e5 5....               win
# ...                                                  ...               ...
# 12417  \n1. e4 {[%clk 0:02:57.7]} 1... e5 {[%clk 0:02...               win
# 12418  \n1. e4 {[%clk 0:02:56.9]} 1... e5 {[%clk 0:02...               win
# 12419  \n1. e4 {[%clk 0:02:57.9]} 1... b6 {[%clk 0:02...           timeout
# 12420  \n1. e4 {[%clk 0:02:59.9]} 1... c5 {[%clk 0:02...        checkmated
# 12421  \n1. d4 {[%clk 0:02:58.7]} 1... d5 {[%clk 0:02...               win
#
#        Result adv
# 0      checkmated
# 1      checkmated
# 2      checkmated
# 3      checkmated
# 4      checkmated
# ...           ...
# 12417     timeout
# 12418    resigned
# 12419         win
# 12420         win
# 12421     timeout
#
# [12421 rows x 13 columns]

# %%
df_parties.to_csv(path_or_buf=r"C:\Users\rasse\_Data_analyst\My Projects\Chess analyse\REDO 122025\Chess_games.csv")
